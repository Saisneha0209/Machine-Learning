# %% [markdown]
# <a href="https://colab.research.google.com/github/Saisneha0209/Machine-Learning/blob/main/%5BDataframe_House_Information%5D_and_SCIKIT_LIBRARY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #house data

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression  #80% is there to train it and the rest of the 20% to be given to the testing data frame...
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.metrics import accuracy_score
import numpy as np
import warnings
warnings.filterwarnings('ignore')
df = pd.read_csv('house_data_large (1).csv')
#print(df)
x=df[["Sqft","Bedrooms","Bathrooms","YearBuilt","LocationCode"]]  #FACTORS TO BE PROVIDED
y=df["Price"]
#print(x)
#print(y)
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)
model=LinearRegression()
model.fit(x_train,y_train)
pred=model.predict(x_test)  #TO PREDICT THE MODEL
#print(pred)#TO FIND THE PREDICTION....
user_input=np.array([[3692,1,1,2015,5]])
u_pred=model.predict(user_input)
#print("SO THIS IS THE PRICE OF THE HOUSE :",(int(u_pred)))
r2=r2_score(y_test,pred)
accuracy=np.sqrt(mean_squared_error(y_test,pred))
print(r2)
# Out:
# 0.9888245851717383

# %%
#to show it diagramatically
import matplotlib.pyplot as plt
df = pd.read_csv('house_data_large (1).csv')
print(df)
x=df[["Sqft","Bedrooms","Bathrooms","YearBuilt","LocationCode"]]
y=df["Price"]
print(x)
print(y)
plt.plot(x,y)#Here it will be line graph..
plt.title("Representation of houses for information")
plt.xlabel('Sqft')
plt.ylabel('Price')
plt.show()
# Out:
#      Sqft  Bedrooms  Bathrooms  YearBuilt  LocationCode       Price
# 0    3774         2          4       2006             1  1279483.77
# 1    1460         4          4       1981             3   748298.12
# 2    1894         2          3       2020             1   768986.29
# 3    1730         5          4       1992             4   871720.14
# 4    1695         5          1       1988             5   834730.66
# ..    ...       ...        ...        ...           ...         ...
# 995  2569         2          1       2015             2   857928.50
# 996   660         4          4       2010             4   570720.48
# 997  3281         1          2       1981             5  1279230.12
# 998  3722         1          3       1995             3  1435726.90
# 999  1628         5          3       1988             5   953762.59
#
# [1000 rows x 6 columns]
#      Sqft  Bedrooms  Bathrooms  YearBuilt  LocationCode
# 0    3774         2          4       2006             1
# ...

# %%
#scikit learn - a library(machine learning algorithms without coding)
#from scikit learn import linear regression....
