# %% [markdown]
# <a href="https://colab.research.google.com/github/Saisneha0209/Machine-Learning/blob/main/FastAPI_Basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install fastapi

# %%
# !pip install uvicorn

# %%
from fastapi import FastAPI
server = FastAPI()
@server.get("/")
def read():
  project = "Colab API"
  status = "active"

  return {
      "api_name":project,
      "current_version":status
  }

# %%
# to run it , type in the terminaluvicorn main:server --reload
