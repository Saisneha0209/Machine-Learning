# %% [markdown]
# <a href="https://colab.research.google.com/github/Saisneha0209/Machine-Learning/blob/main/Reinforcement_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #REINFORCEMENT LEARNING!!

# %%
reward = 0
for num in range(1,101):
  if num%2==0:
    reward+=1
print("Reward",reward)
# Out:
# Reward 50

# %%
#Random value:-
import random
rl = {"A":0,"B":0}
for i in range(100):
  turn = random.choice(["A","B"])
print(turn)
reward=1 if turn=="A" else 0
rl[turn]+=reward
print(rl)
# Out:
# B
# {'A': 0, 'B': 0}

# %%
#next level
rl = {"A":0,"B":0}
for i in range(100):
   turn = "A" if rl["A"]>=rl["B"] else "B"
print(turn)
reward=1 if turn=="A" else 0
rl[turn]+=reward
print(rl)
# Out:
# A
# {'A': 1, 'B': 0}

# %%
#next step
import random
rl = {"A":0,"B":0}
choclate = 0
count = 0
while choclate<100:
   turn = "A" if rl["A"]>=rl["B"] else "B"
   print(turn)
   reward=1 if turn=="A" else 0
   rl[turn]+=reward
   choclate+=reward
   count = count+1
   print("Goal reached")
   print(count)
   print(rl)
# Out:
# A
# Goal reached
# 1
# {'A': 1, 'B': 0}
# A
# Goal reached
# 2
# {'A': 2, 'B': 0}
# A
# Goal reached
# 3
# {'A': 3, 'B': 0}
# A
# Goal reached
# 4
# {'A': 4, 'B': 0}
# A
# Goal reached
# 5
# {'A': 5, 'B': 0}
# A
# Goal reached
# 6
# {'A': 6, 'B': 0}
# A
# Goal reached
# 7
# {'A': 7, 'B': 0}
# A
# Goal reached
# 8
# {'A': 8, 'B': 0}
# A
# Goal reached
# 9
# {'A': 9, 'B': 0}
# A
# Goal reached
# 10
# {'A': 10, 'B': 0}
# A
# Goal reached
# 11
# {'A': 11, 'B': 0}
# A
# Goal reached
# 12
# {'A': 12, 'B': 0}
# A
# Goal reached
# 13
# {'A': 13, 'B': 0}
# A
# Goal reached
# 14
# {'A': 14, 'B': 0}
# A
# Goal reached
# 15
# {'A': 15, 'B': 0}
# A
# Goal reached
# 16
# {'A': 16, 'B': 0}
# A
# Goal reached
# 17
# {'A': 17, 'B': 0}
# A
# Goal reached
# 18
# {'A': 18, 'B': 0}
# A
# Goal reached
# 19
# {'A': 19, 'B': 0}
# A
# Goal reached
# 20
# {'A': 20, 'B': 0}
# A
# Goal reached
# 21
# {'A': 21, 'B': 0}
# A
# Goal reached
# 22
# {'A': 22, 'B': 0}
# A
# Goal reached
# 23
# {'A': 23, 'B': 0}
# A
# ...

# %%
#next step
import random
rl = {"A":-10,"B":-5}
choclate = 0
count = 0
while choclate<100:
  turn = "A" if rl["A"]>=rl["B"] else "B"
  print(turn)
  reward=1 if turn=="A" else -1
  rl[turn]+=reward
  choclate+=reward
  count = count+1
  print("Goal reached")
  print(count)
  print("rl",rl)
# Out:
# B
# Goal reached
# 1
# rl {'A': -10, 'B': -6}
# B
# Goal reached
# 2
# rl {'A': -10, 'B': -7}
# B
# Goal reached
# 3
# rl {'A': -10, 'B': -8}
# B
# Goal reached
# 4
# rl {'A': -10, 'B': -9}
# B
# Goal reached
# 5
# rl {'A': -10, 'B': -10}
# A
# Goal reached
# 6
# rl {'A': -9, 'B': -10}
# A
# Goal reached
# 7
# rl {'A': -8, 'B': -10}
# A
# Goal reached
# 8
# rl {'A': -7, 'B': -10}
# A
# Goal reached
# 9
# rl {'A': -6, 'B': -10}
# A
# Goal reached
# 10
# rl {'A': -5, 'B': -10}
# A
# Goal reached
# 11
# rl {'A': -4, 'B': -10}
# A
# Goal reached
# 12
# rl {'A': -3, 'B': -10}
# A
# Goal reached
# 13
# rl {'A': -2, 'B': -10}
# A
# Goal reached
# 14
# rl {'A': -1, 'B': -10}
# A
# Goal reached
# 15
# rl {'A': 0, 'B': -10}
# A
# Goal reached
# 16
# rl {'A': 1, 'B': -10}
# A
# Goal reached
# 17
# rl {'A': 2, 'B': -10}
# A
# Goal reached
# 18
# rl {'A': 3, 'B': -10}
# A
# Goal reached
# 19
# rl {'A': 4, 'B': -10}
# A
# Goal reached
# 20
# rl {'A': 5, 'B': -10}
# A
# Goal reached
# 21
# ...

# %% [markdown]
# #TIC TAC TOE:-

# %%
winning_moves=[[1,2,3],[4,5,6],[7,8,9],[1,4,7],[2,5,8],[3,6,9],[1,5,9],[3,5,7]]
def AI_Turns():
    return [[None]*3 for i in range(3)]
AI_Turns()
print(AI_Turns())
print("------------------------------------------")
print("   |   |   ")
print("---+---+---")
print("   |   |   ")
print("---+---+---")
print("   |   |   ")
# Out:
# [[None, None, None], [None, None, None], [None, None, None]]
# ------------------------------------------
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
