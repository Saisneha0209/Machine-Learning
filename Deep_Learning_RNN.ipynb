# %% [markdown]
# <a href="https://colab.research.google.com/github/Saisneha0209/Machine-Learning/blob/main/Deep_Learning_RNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#RNN!!
#Sequential data:-Human - Oriented
#text to speech
#text to text
#speech to speech
#NLP(Natural Language Processing)
#CV(Computer Vision).......
#ML(Machine Learning)......

# %%
#ML:-Statical Data,Predictions of House Price or Whether!!!
#NLP:-tALKING ABOUT listening,writing in language recoginition!!!
#CV:-By visualising!!!
#NLP AND CV ARE PART OF AI AND DIFF TEHCNOLOGY!!!
#LSTM:-Long short term!!!
#GRU!!!
#Transformer that changed the ERA!!!

# %%
#SENTENCE STRUCTURE:-GRAMMAR.....
#CONTEXT .....
#SEMANTIC ....
#CORRECT .....
#PUNCTUATION.....
